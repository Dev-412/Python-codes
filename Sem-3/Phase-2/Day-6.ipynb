# %%
d ={
    "1":"one",
    "2":"two",
    "3":"three",
    "4":"four",
    "5":"five",
    "6":"six",
    "7":"seven",
    "8":"Eight",
    "9":"nine",
    "10":"ten",
    "11":"eleven",
    "12":"twelve",
    "13":"thirteen",
    "14":"fourteen",
    "15":"fifteen",
    "16":"sixteen",
    "17":"seventeen",
    "18":"Eighteen",
    "19":"nineteen",
    "20":"twenty",
    "30":"thirty",
    "40":"fourty",
    "50":"fifty",
    "60":"sixty",
    "70":"seventy",
    "80":"eighty",
    "90":"ninty",
    "100":"hundread"
}

n = int(input("enter number"))
x=str(n)
print(type(n))
if(n<=1000):
    if(n<=20):
        print(d[x])
    elif(n>20 and n<100):
        if(n%10==0):
            a=str(n)
            print(d[a])
        else:
            a = n//10
            a=a*10
            a = str(a)
        
            b=n%10
            b=str(b)
            print(d[a]+" "+d[b])
    elif(n>=100 and n<1000):
        if(n%100==0):
            p=n//100
            p=str(p)
    
            print(d[p]+"hundread")
        elif(n%10==0 or n%100<20):
            a=n%100
            a=str(a)
            c = n//100
            c=str(c)
            print(d[c]+"Hundread "+d[a])
            
        else:
            c = n//100
            c=str(c)
        
            a = n//10
            a=a%10
            a=a*10
            a = str(a)
        
            b=n%10
            b=str(b)
            print(d[c]+"Hundread "+d[a]+" "+d[b])
    else:
        print("one thousand")
# Out:
# enter number0912
# <class 'int'>
# nineHundread twelve

# %%
def Demo(n):
    
    if(n<=20):
        return d[n]
    if(n<100):
        if(n%10==0):
            return d[n]
        else:
            return d[(n/10)*10]+d[n%10]
    if(n<1000):
        if(n%100==0):
            return d[n/100]+"hundread"
        else:
            return d[n/100]+"hundread"+Demo(n%100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-2a419c7fc68c> in <module>
#      14         else:
#      15             return d[n/100]+"hundread"+Demo(n%100)
# ---> 16 Demo(n)
#
# <ipython-input-53-2a419c7fc68c> in Demo(n)
#      13             return d[n/100]+"hundread"
#      14         else:
# ---> 15             return d[n/100]+"hundread"+Demo(n%100)
#      16 Demo(n)
#
# KeyError: 1.5

# %%
a = {1,2,3,4,5,6}

a=frozenset(a)

b= {3,4,5,6,7,8}
print(a)

c={1,2}

print(c.issubset(a))
# Out:
# frozenset({1, 2, 3, 4, 5, 6})
# True

# %%
x ="hello my name is"
d={}
for i in x:
    d[i]=x.count(i)
    
print(d)

z=sorted(d.items(),key=lambda i:i[1] ,reverse=True)
print(z)
# Out:
# {'h': 1, 'e': 2, 'l': 2, 'o': 1, ' ': 3, 'm': 2, 'y': 1, 'n': 1, 'a': 1, 'i': 1, 's': 1}
# [('y', 1), ('s', 1), ('o', 1), ('n', 1), ('m', 2), ('l', 2), ('i', 1), ('h', 1), ('e', 2), ('a', 1), (' ', 3)]
