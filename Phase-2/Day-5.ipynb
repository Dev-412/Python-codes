# %%
d={}
a=input("Enter smthing")
b=input("Enter smthing")
d[a]=b
print(d)
# Out:
# Enter smthinghaha
# Enter smthinghi
# {'haha': 'hi'}

# %%
d={}
for i in range(3):
    a= input("Enter name")
    b = int(input("Enter runs"))
    d[a]=b
p =max(d.values())
q = min(d.values())

for i,j in (d.items()):
    if j==p:
        print(f"max = {i}")
    if j==q:
        print(f"min = {i}")

d["virat"]=183

x = sum(d.values())
print(f"avg = {x/len(d)}")
# Out:
# Enter namedev
# Enter runs10
# Enter namehet
# Enter runs50
# Enter namerahul
# Enter runs100
# min = dev
# max = rahul
# avg = 85.75

# %%
d={"dev":10,"het":5}
print(max(d.values()))
print(min(d.values()))
print(len(d))
p=max(d.values())
for i,j in (d.items()):
    if j==p:
        print(i)
# Out:
# 10
# 5
# 2
# dev

# %%
name=["A","B","C","D"]
marks=[10,20,30]
z = dict(zip(name,marks))

print(z)
# Out:
# {'A': 10, 'B': 20, 'C': 30}

# %%
d={"A":[10,20,30],"B":[1,2,3]}

print(d.get("A"))
print(d["A"][-1])
# Out:
# [10, 20, 30]
# 30

# %%
d["A"][-1]
# Out:
# 30

# %%
x ="hello my name is"
d={}
for i in x:
    d[i]=x.count(i)
    
print(d)
# Out:
# {'hello': 1, 'my': 1, 'name': 1, 'is': 1}

# %%
if(d.get("x")==None):
    print("X")
# Out:
# X

# %%
x ="hi hello how are you im fine are you fin"
x=x.split(" ")
print(x)
d={}
for i in x:
    p=i[0]
    l =[]
    for j in x:
        
        if(p==j[0]):
            l.append(j)
    print(l)
    d[p]=l
    
print(d)
# Out:
# ['hi', 'hello', 'how', 'are', 'you', 'im', 'fine', 'are', 'you', 'fin']
# ['hi', 'hello', 'how']
# ['hi', 'hello', 'how']
# ['hi', 'hello', 'how']
# ['are', 'are']
# ['you', 'you']
# ['im']
# ['fine', 'fin']
# ['are', 'are']
# ['you', 'you']
# ['fine', 'fin']
# {'h': ['hi', 'hello', 'how'], 'a': ['are', 'are'], 'y': ['you', 'you'], 'i': ['im'], 'f': ['fine', 'fin']}
