# %%
x = "Hello my name is Dev"
print(len(x))
print(x[17])
print(x[0:15:1])

# %%
x = input("Enter String ")
if((len(x)%2)==0):
    print(x[0])
    print(x[len(x)-1])
else:
    print(x[len(x)-1]+x[1:len(x)-1]+x[0])

# %%
x = "hello my name is Dev"
print(x.count("l",0,5))

print(x.replace("Dev","het"))
print(x.split(" "))
print("@".join(x))

# %%
x = input("Enter String")

y = x.count("a")

if(y%2!=0):
    x = x.replace("a","@")
    x = x.lower()
    print(x)
else:
    z =x.split("a")
    print(z)
    print(len(z))
    print(len(x))
# Out:
# Enter Stringaa
# ['aa']
# 1
# 2

# %%
x = "Dhruv Dhoni"
y = x.find("r")
if(y==-1):
    print("NO r")
else:
    print(y)
# Out:
# 2

# %%
x="baca"
print(x.rfind("a"))
# Out:
# 3

# %%
x="whwhahahahaha32322323232323mofef"

print(x.isalnum())
print(x.isalpha())
print(x.isdigit())
print(x.isnumeric())
print(x.isupper())
print(x.islower())
print(x.istitle())
# Out:
# True
# False
# False
# False
# False
# True
# False
