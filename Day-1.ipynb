# %%
import pandas as pd
import numpy as np

ds = pd.Series([10,20,30],index=['D','E','V'],dtype='float',name='dev')
print(ds)

# %%
import pandas as pd
import numpy as np

ds = pd.Series({"d":40,"e":100,"v":40},dtype='float',name='dev')
print(ds)
# Out:
# d     40.0
# e    100.0
# v     40.0
# Name: dev, dtype: float64

# %%
import pandas as pd
import numpy as np

ds = pd.Series(np.array([10,20,30]),index=['D','E','V'],dtype='float',name='dev')
print(ds)
# Out:
# D    10.0
# E    20.0
# V    30.0
# Name: dev, dtype: float64

# %%
ds = pd.DataFrame([['d','e','v'],[10,20,30],['h','e','t']],index=['a','b','c'],columns=['p','q','r'])
print(ds)
# Out:
#     p   q   r
# a   d   e   v
# b  10  20  30
# c   h   e   t

# %%
ds = pd.DataFrame({'name':['dev','het','jay'],"marks":[10,20,30],'gpa':[7,7.5,6.5]})
print(ds)
# Out:
#   name  marks  gpa
# 0  dev     10  7.0
# 1  het     20  7.5
# 2  jay     30  6.5

# %%
df= pd.read_csv('train.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.index
df.columns
df.size
df.shape
df.values
df.dtypes
df.ndim
df.T  #transpose
df = df.set_index('Name')

# %%
df = df.reset_index()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds1 = pd.DataFrame({'name':['dev','het','jay'],"marks":[10,20,30],'CGPI':[7,7.5,6.5]},index=['V','H','A'])
print(ds1)
# Out:
#   name  marks  CGPI
# V  dev     10   7.0
# H  het     20   7.5
# A  jay     30   6.5

# %%
ds1.set_index('name',drop=True)

# %%
ds1.set_index('name',drop=False)
# Out:
#      name  marks  CGPI
# name
# dev   dev     10   7.0
# het   het     20   7.5
# jay   jay     30   6.5

# %%
print(ds1)
# Out:
#   name  marks  CGPI
# 0  dev     10   7.0
# 1  het     20   7.5
# 2  jay     30   6.5

# %%
ds1 = ds1.reset_index()

# %%
df = pd.read_csv('train.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Name',"Age"]]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
type(df['Name'])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[2,3] #particular position
df.iloc[2] #3rd row
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[1:10,2:5]
# Out:
#    Pclass                                               Name     Sex
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                           Allen, Mr. William Henry    male
# 5       3                                   Moran, Mr. James    male
# 6       1                            McCarthy, Mr. Timothy J    male
# 7       3                     Palsson, Master. Gosta Leonard    male
# 8       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)  female

# %%
df =df.set_index('Name')

# %%
df.index
# Out:
# Index(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        ...
#        'Markun, Mr. Johann', 'Dahlberg, Miss. Gerda Ulrika',
#        'Banfield, Mr. Frederick James', 'Sutehall, Mr. Henry Jr',
#        'Rice, Mrs. William (Margaret Norton)', 'Montvila, Rev. Juozas',
#        'Graham, Miss. Margaret Edith',
#        'Johnston, Miss. Catherine Helen "Carrie"', 'Behr, Mr. Karl Howell',
#        'Dooley, Mr. Patrick'],
#       dtype='object', name='Name', length=891)

# %%
df.loc['Braund, Mr. Owen Harris']
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                   22
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df.loc['Braund, Mr. Owen Harris','PassengerId':'Age']
# Out:
# PassengerId       1
# Survived          0
# Pclass            3
# Sex            male
# Age              22
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
ds1 = pd.DataFrame([[10,20,30],[40,50,60],[70,80,90]],index=['a','b','c'],columns=['p','q','r'])
print(ds1)
# Out:
#     p   q   r
# a  10  20  30
# b  40  50  60
# c  70  80  90

# %%
ds1.loc['b','q']=100

# %%
ds1.loc['b','q']
# Out:
# 100

# %%
ds1.loc[:,'r']
# Out:
# a    30
# b    60
# c    90
# Name: r, dtype: int64

# %%
ds1['D']=7

# %%
ds1
# Out:
#     p    q   r  D
# a  10   20  30  7
# b  40  100  60  7
# c  70   80  90  7

# %%
ds1['D']=ds1['p']*ds1['q']

# %%
ds1
# Out:
#     p    q   r     D
# a  10   20  30   200
# b  40  100  60  4000
# c  70   80  90  5600

# %%
ds1.loc['a':'c','p':'r']=7

# %%
ds1
# Out:
#    p  q  r     D
# a  7  7  7   200
# b  7  7  7  4000
# c  7  7  7  5600
